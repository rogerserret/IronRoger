# %%
import pandas as pd

# %%
df1 = pd.read_csv('craftsandcocktails.csv', dtype = str)

# %%
df2 = pd.read_csv('cocktail_recipes.csv', dtype = str)

# %%
pd.set_option('display.max_columns', None) # to see all columns
df1.columns
# Out:
# Index(['aggregated_pin_data/done', 'aggregated_pin_data/saves', 'alt_text',
#        'board/id', 'board/image_thumbnail_url', 'board/is_collaborative',
#        'board/name', 'board/url', 'carousel_data', 'created_at',
#        ...
#        'story_pin_data/pages_preview/0/blocks/1/user/image_large_url',
#        'story_pin_data/pages_preview/0/blocks/1/user/image_small_url',
#        'story_pin_data/pages_preview/0/blocks/1/user/username',
#        'story_pin_data/pages_preview/0/blocks/1/user_id',
#        'story_pin_data/total_video_duration', 'story_pin_data_id', 'title',
#        'video_status', 'video_status_message', 'videos'],
#       dtype='object', length=1354)

# %%
df1.head()

# we only need columns 'created_at' and
# Out:
#   aggregated_pin_data/done aggregated_pin_data/saves alt_text  \
# 0                        0                         4      NaN
# 1                        0                         5      NaN
# 2                        0                         7      NaN
# 3                        0                         1      NaN
# 4                        0                       457      NaN
#
#              board/id                          board/image_thumbnail_url  \
# 0  153755843467303547  https://i.pinimg.com/upload/153755843467303547...
# 1  153755843467303547  https://i.pinimg.com/upload/153755843467303547...
# 2  153755843467303547  https://i.pinimg.com/upload/153755843467303547...
# 3  153755843467356948  https://i.pinimg.com/upload/153755843467356948...
# 4  153755843467248008  https://i.pinimg.com/upload/153755843467248008...
#
#   board/is_collaborative                 board/name  \
# 0                  false  CRAFT & COCKTAILS RECIPES
# ...
