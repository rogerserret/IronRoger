# %% [markdown]
# # Spotipy API
#
# Create an Spotify account and follow these steps to register an app: https://developer.spotify.com/documentation/general/guides/app-settings/
#
# After the app is created, you can see it on your dashboard
# https://developer.spotify.com/dashboard/applications
#
# Click on it and you'll find the client id and client secret.

# %% [markdown]
# #### Authentification

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# # Password protection section

# %%
import getpass

# %%
client_id=str(getpass.getpass('enter your client id'))
client_secret=str(getpass.getpass('enter your client secret')) 
# this helps us protect our password
# Out:
# enter your client id········
# enter your client secret········

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`

# %%
results = sp.search(q='Courtney Bartnett',limit=50)

# %% [markdown]
# Explore the object returned by the request:

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Courtney+Bartnett&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lUc4iyCvw8DxpZa4Fryej'},
#      'href': 'https://api.spotify.com/v1/albums/5lUc4iyCvw8DxpZa4Fryej',
#      'id': '5lUc4iyCvw8DxpZa4Fryej',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b1a128867e27ffc617e8a6e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b1a128867e27ffc617e8a6e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b1a128867e27ffc617e8a6e',
#        'width': 64}],
#      'name': 'The Double EP: A Sea of Split Peas',
#      'release_date': '2013',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5lUc4iyCvw8DxpZa4Fryej'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 312226,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBXFC1300066'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LueS3mbuB1yaJNN0Ale6U'},
#     'href': 'https://api.spotify.com/v1/tracks/3LueS3mbuB1yaJNN0Ale6U',
#     'id': '3LueS3mbuB1yaJNN0Ale6U',
#     'is_local': False,
#     'name': 'Avant Gardener',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b3c4b383d4084fbd4494d24bfc4d034a261861cf?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3LueS3mbuB1yaJNN0Ale6U'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3InSvUCYvJ5XWg6PegGNCv'},
#      'href': 'https://api.spotify.com/v1/albums/3InSvUCYvJ5XWg6PegGNCv',
#      'id': '3InSvUCYvJ5XWg6PegGNCv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f1904e84048385bd801ac7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f1904e84048385bd801ac7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f1904e84048385bd801ac7',
#        'width': 64}],
#      'name': 'Things Take Time, Take Time',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3InSvUCYvJ5XWg6PegGNCv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 225632,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX722100369'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LQcvjqp41rK1ZBuCaKGbb'},
#     'href': 'https://api.spotify.com/v1/tracks/0LQcvjqp41rK1ZBuCaKGbb',
#     'id': '0LQcvjqp41rK1ZBuCaKGbb',
#     'is_local': False,
#     'name': 'Before You Gotta Go',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6482a0c7126784efcb1798352a4ca20cfed983e8?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0LQcvjqp41rK1ZBuCaKGbb'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3InSvUCYvJ5XWg6PegGNCv'},
#      'href': 'https://api.spotify.com/v1/albums/3InSvUCYvJ5XWg6PegGNCv',
#      'id': '3InSvUCYvJ5XWg6PegGNCv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f1904e84048385bd801ac7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f1904e84048385bd801ac7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f1904e84048385bd801ac7',
#        'width': 64}],
#      'name': 'Things Take Time, Take Time',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3InSvUCYvJ5XWg6PegGNCv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 271206,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX722100366'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4DtQQ82VSTgYfsCBSxvK9k'},
#     'href': 'https://api.spotify.com/v1/tracks/4DtQQ82VSTgYfsCBSxvK9k',
#     'id': '4DtQQ82VSTgYfsCBSxvK9k',
#     'is_local': False,
#     'name': 'Rae Street',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71561875bf8b3388b84b915a4f9dadcbd39895e8?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4DtQQ82VSTgYfsCBSxvK9k'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3InSvUCYvJ5XWg6PegGNCv'},
#      'href': 'https://api.spotify.com/v1/albums/3InSvUCYvJ5XWg6PegGNCv',
#      'id': '3InSvUCYvJ5XWg6PegGNCv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f1904e84048385bd801ac7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f1904e84048385bd801ac7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f1904e84048385bd801ac7',
#        'width': 64}],
#      'name': 'Things Take Time, Take Time',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3InSvUCYvJ5XWg6PegGNCv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 168074,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX722100373'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5MI8umTu0luQ4wQPm87adK'},
#     'href': 'https://api.spotify.com/v1/tracks/5MI8umTu0luQ4wQPm87adK',
#     'id': '5MI8umTu0luQ4wQPm87adK',
#     'is_local': False,
#     'name': 'Write A List of Things To Look Forward To',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f8ce030f5780a9994b63077cc78ce6ab57d95da?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5MI8umTu0luQ4wQPm87adK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6PosCDToF5fOdEjTI5PsDX'},
#      'href': 'https://api.spotify.com/v1/albums/6PosCDToF5fOdEjTI5PsDX',
#      'id': '6PosCDToF5fOdEjTI5PsDX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a5f79147181976a019edf286',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a5f79147181976a019edf286',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a5f79147181976a019edf286',
#        'width': 64}],
#      'name': 'Sometimes I Sit and Think, and Sometimes I Just Sit',
#      'release_date': '2015-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6PosCDToF5fOdEjTI5PsDX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 230560,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX721400144'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gsn3NxWLA0s0g9TmQlMri'},
#     'href': 'https://api.spotify.com/v1/tracks/7gsn3NxWLA0s0g9TmQlMri',
#     'id': '7gsn3NxWLA0s0g9TmQlMri',
#     'is_local': False,
#     'name': 'Pedestrian at Best',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7b3390b72c48b244d78b4d62a302bd4c47ce214e?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7gsn3NxWLA0s0g9TmQlMri'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gspAQIAH8nJUrMYgXjCJ2'},
#        'href': 'https://api.spotify.com/v1/artists/5gspAQIAH8nJUrMYgXjCJ2',
#        'id': '5gspAQIAH8nJUrMYgXjCJ2',
#        'name': 'Kurt Vile',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gspAQIAH8nJUrMYgXjCJ2'}],
#      'available_markets': ['AE',
#       'AG',
#       'AO',
#       'AR',
#       'BB',
#       'BD',
#       'BF',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'DJ',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EG',
#       'GA',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LY',
#       'MA',
#       'MG',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PS',
#       'PY',
#       'QA',
#       'RW',
#       'SA',
#       'SC',
#       'SG',
#       'SL',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TN',
#       'TT',
#       'TW',
#       'TZ',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Va3brVieuLkZIjJYf3orN'},
#      'href': 'https://api.spotify.com/v1/albums/6Va3brVieuLkZIjJYf3orN',
#      'id': '6Va3brVieuLkZIjJYf3orN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a414004f993c28acedee0463',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a414004f993c28acedee0463',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a414004f993c28acedee0463',
#        'width': 64}],
#      'name': 'Lotta Sea Lice',
#      'release_date': '2017-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:6Va3brVieuLkZIjJYf3orN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gspAQIAH8nJUrMYgXjCJ2'},
#       'href': 'https://api.spotify.com/v1/artists/5gspAQIAH8nJUrMYgXjCJ2',
#       'id': '5gspAQIAH8nJUrMYgXjCJ2',
#       'name': 'Kurt Vile',
#       'type': 'artist',
#       'uri': 'spotify:artist:5gspAQIAH8nJUrMYgXjCJ2'}],
#     'available_markets': ['AE',
#      'AG',
#      'AO',
#      'AR',
#      'BB',
#      'BD',
#      'BF',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'DJ',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'ID',
#      'IL',
#      'IN',
#      'IQ',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LY',
#      'MA',
#      'MG',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PS',
#      'PY',
#      'QA',
#      'RW',
#      'SA',
#      'SC',
#      'SG',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TN',
#      'TT',
#      'TW',
#      'TZ',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 379853,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMTD1709998'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72EIWFWM88oEnIgxQEoqQz'},
#     'href': 'https://api.spotify.com/v1/tracks/72EIWFWM88oEnIgxQEoqQz',
#     'id': '72EIWFWM88oEnIgxQEoqQz',
#     'is_local': False,
#     'name': 'Over Everything',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/48caf0ac509bed46ae10bb6c69ac7a9dbb7c07ab?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:72EIWFWM88oEnIgxQEoqQz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6PosCDToF5fOdEjTI5PsDX'},
#      'href': 'https://api.spotify.com/v1/albums/6PosCDToF5fOdEjTI5PsDX',
#      'id': '6PosCDToF5fOdEjTI5PsDX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a5f79147181976a019edf286',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a5f79147181976a019edf286',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a5f79147181976a019edf286',
#        'width': 64}],
#      'name': 'Sometimes I Sit and Think, and Sometimes I Just Sit',
#      'release_date': '2015-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6PosCDToF5fOdEjTI5PsDX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 292853,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX721400147'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tCQCy7SCL2xg2QNe2inmd'},
#     'href': 'https://api.spotify.com/v1/tracks/6tCQCy7SCL2xg2QNe2inmd',
#     'id': '6tCQCy7SCL2xg2QNe2inmd',
#     'is_local': False,
#     'name': 'Depreston',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a7ba9aee31d08f41ffffd8e8ee055e68b6b5151?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6tCQCy7SCL2xg2QNe2inmd'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5eVGVLpLcMEjuP1BNdlKWz'},
#      'href': 'https://api.spotify.com/v1/albums/5eVGVLpLcMEjuP1BNdlKWz',
#      'id': '5eVGVLpLcMEjuP1BNdlKWz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303d5d62dba112f14ca51ca21',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203d5d62dba112f14ca51ca21',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103d5d62dba112f14ca51ca21',
#        'width': 64}],
#      'name': 'Day of the Dead',
#      'release_date': '2016-05-20',
#      'release_date_precision': 'day',
#      'total_tracks': 59,
#      'type': 'album',
#      'uri': 'spotify:album:5eVGVLpLcMEjuP1BNdlKWz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 320719,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL1600024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7rlH5IVzRc5eCMiURVoUrI'},
#     'href': 'https://api.spotify.com/v1/tracks/7rlH5IVzRc5eCMiURVoUrI',
#     'id': '7rlH5IVzRc5eCMiURVoUrI',
#     'is_local': False,
#     'name': 'New Speedway Boogie',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8e1eb9ee050eedd8108a6072861c5d363eab4044?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7rlH5IVzRc5eCMiURVoUrI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3InSvUCYvJ5XWg6PegGNCv'},
#      'href': 'https://api.spotify.com/v1/albums/3InSvUCYvJ5XWg6PegGNCv',
#      'id': '3InSvUCYvJ5XWg6PegGNCv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f1904e84048385bd801ac7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f1904e84048385bd801ac7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f1904e84048385bd801ac7',
#        'width': 64}],
#      'name': 'Things Take Time, Take Time',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3InSvUCYvJ5XWg6PegGNCv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 217858,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX722100372'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0vPkKjAbhVGjUDKcvb316M'},
#     'href': 'https://api.spotify.com/v1/tracks/0vPkKjAbhVGjUDKcvb316M',
#     'id': '0vPkKjAbhVGjUDKcvb316M',
#     'is_local': False,
#     'name': "If I Don't Hear From You Tonight",
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/edfe238006141eca3689075d90c2bd43e9e4408f?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0vPkKjAbhVGjUDKcvb316M'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lUc4iyCvw8DxpZa4Fryej'},
#      'href': 'https://api.spotify.com/v1/albums/5lUc4iyCvw8DxpZa4Fryej',
#      'id': '5lUc4iyCvw8DxpZa4Fryej',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b1a128867e27ffc617e8a6e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b1a128867e27ffc617e8a6e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b1a128867e27ffc617e8a6e',
#        'width': 64}],
#      'name': 'The Double EP: A Sea of Split Peas',
#      'release_date': '2013',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5lUc4iyCvw8DxpZa4Fryej'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 208320,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBXFC1300067'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KM7h4kz6oTrjSZX9AUXbL'},
#     'href': 'https://api.spotify.com/v1/tracks/1KM7h4kz6oTrjSZX9AUXbL',
#     'id': '1KM7h4kz6oTrjSZX9AUXbL',
#     'is_local': False,
#     'name': 'History Eraser',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/89b668b6755f3acbd74e351936c7c9abe2ab7048?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1KM7h4kz6oTrjSZX9AUXbL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jTCDh0kJpPvp8ZcB9vecP'},
#      'href': 'https://api.spotify.com/v1/albums/7jTCDh0kJpPvp8ZcB9vecP',
#      'id': '7jTCDh0kJpPvp8ZcB9vecP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b849df278412488867c055e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b849df278412488867c055e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b849df278412488867c055e2',
#        'width': 64}],
#      'name': 'I’ll Be Your Mirror',
#      'release_date': '2021-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7jTCDh0kJpPvp8ZcB9vecP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 147666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72102533'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6WhararZxL2vL7XyL3UO0N'},
#     'href': 'https://api.spotify.com/v1/tracks/6WhararZxL2vL7XyL3UO0N',
#     'id': '6WhararZxL2vL7XyL3UO0N',
#     'is_local': False,
#     'name': 'I’ll Be Your Mirror',
#     'popularity': 45,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6WhararZxL2vL7XyL3UO0N'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5lUc4iyCvw8DxpZa4Fryej'},
#      'href': 'https://api.spotify.com/v1/albums/5lUc4iyCvw8DxpZa4Fryej',
#      'id': '5lUc4iyCvw8DxpZa4Fryej',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b1a128867e27ffc617e8a6e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b1a128867e27ffc617e8a6e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b1a128867e27ffc617e8a6e',
#        'width': 64}],
#      'name': 'The Double EP: A Sea of Split Peas',
#      'release_date': '2013',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5lUc4iyCvw8DxpZa4Fryej'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 350853,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBXFC1300069'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4bnMZOiXBw6aQUKIljx7H1'},
#     'href': 'https://api.spotify.com/v1/tracks/4bnMZOiXBw6aQUKIljx7H1',
#     'id': '4bnMZOiXBw6aQUKIljx7H1',
#     'is_local': False,
#     'name': 'Anonymous Club',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/50906eb1a4d75ca40fe24816950ba43317691b38?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4bnMZOiXBw6aQUKIljx7H1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gspAQIAH8nJUrMYgXjCJ2'},
#        'href': 'https://api.spotify.com/v1/artists/5gspAQIAH8nJUrMYgXjCJ2',
#        'id': '5gspAQIAH8nJUrMYgXjCJ2',
#        'name': 'Kurt Vile',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gspAQIAH8nJUrMYgXjCJ2'}],
#      'available_markets': ['AE',
#       'AG',
#       'AO',
#       'AR',
#       'BB',
#       'BD',
#       'BF',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'DJ',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EG',
#       'GA',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LY',
#       'MA',
#       'MG',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PS',
#       'PY',
#       'QA',
#       'RW',
#       'SA',
#       'SC',
#       'SG',
#       'SL',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TN',
#       'TT',
#       'TW',
#       'TZ',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Va3brVieuLkZIjJYf3orN'},
#      'href': 'https://api.spotify.com/v1/albums/6Va3brVieuLkZIjJYf3orN',
#      'id': '6Va3brVieuLkZIjJYf3orN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a414004f993c28acedee0463',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a414004f993c28acedee0463',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a414004f993c28acedee0463',
#        'width': 64}],
#      'name': 'Lotta Sea Lice',
#      'release_date': '2017-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:6Va3brVieuLkZIjJYf3orN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gspAQIAH8nJUrMYgXjCJ2'},
#       'href': 'https://api.spotify.com/v1/artists/5gspAQIAH8nJUrMYgXjCJ2',
#       'id': '5gspAQIAH8nJUrMYgXjCJ2',
#       'name': 'Kurt Vile',
#       'type': 'artist',
#       'uri': 'spotify:artist:5gspAQIAH8nJUrMYgXjCJ2'}],
#     'available_markets': ['AE',
#      'AG',
#      'AO',
#      'AR',
#      'BB',
#      'BD',
#      'BF',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'DJ',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'ID',
#      'IL',
#      'IN',
#      'IQ',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LY',
#      'MA',
#      'MG',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PS',
#      'PY',
#      'QA',
#      'RW',
#      'SA',
#      'SC',
#      'SG',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TN',
#      'TT',
#      'TW',
#      'TZ',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 293200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMTD1710002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/004vVYQv7qTUoyzje9AqxY'},
#     'href': 'https://api.spotify.com/v1/tracks/004vVYQv7qTUoyzje9AqxY',
#     'id': '004vVYQv7qTUoyzje9AqxY',
#     'is_local': False,
#     'name': 'Continental Breakfast',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b5ccfad7a1011d3f2b8fa7c78e609fda5d9e1894?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:004vVYQv7qTUoyzje9AqxY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3InSvUCYvJ5XWg6PegGNCv'},
#      'href': 'https://api.spotify.com/v1/albums/3InSvUCYvJ5XWg6PegGNCv',
#      'id': '3InSvUCYvJ5XWg6PegGNCv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305f1904e84048385bd801ac7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205f1904e84048385bd801ac7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105f1904e84048385bd801ac7',
#        'width': 64}],
#      'name': 'Things Take Time, Take Time',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3InSvUCYvJ5XWg6PegGNCv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 165312,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX722100367'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6oxQ3SW8ebfXgthltey3aN'},
#     'href': 'https://api.spotify.com/v1/tracks/6oxQ3SW8ebfXgthltey3aN',
#     'id': '6oxQ3SW8ebfXgthltey3aN',
#     'is_local': False,
#     'name': 'Sunfair Sundown',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d1c41870ce486af077a81c65dc793f5a4a3301de?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6oxQ3SW8ebfXgthltey3aN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3l7JWewI3ZByxaT5BCgRx2'},
#      'href': 'https://api.spotify.com/v1/albums/3l7JWewI3ZByxaT5BCgRx2',
#      'id': '3l7JWewI3ZByxaT5BCgRx2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dbb413d3be0911dd96870e8d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dbb413d3be0911dd96870e8d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dbb413d3be0911dd96870e8d',
#        'width': 64}],
#      'name': 'Tell Me How You Really Feel',
#      'release_date': '2018-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3l7JWewI3ZByxaT5BCgRx2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 281586,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX721700210'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/19nUjmaqEhWvOtKk72NXGC'},
# ...
#        'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#        'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#        'name': 'Courtney Barnett',
#        'type': 'artist',
#        'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3l7JWewI3ZByxaT5BCgRx2'},
#      'href': 'https://api.spotify.com/v1/albums/3l7JWewI3ZByxaT5BCgRx2',
#      'id': '3l7JWewI3ZByxaT5BCgRx2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dbb413d3be0911dd96870e8d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dbb413d3be0911dd96870e8d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dbb413d3be0911dd96870e8d',
#        'width': 64}],
#      'name': 'Tell Me How You Really Feel',
#      'release_date': '2018-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3l7JWewI3ZByxaT5BCgRx2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 238253,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBX721700212'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/38O0SN9P3sC0UFLsgLqLju'},
#     'href': 'https://api.spotify.com/v1/tracks/38O0SN9P3sC0UFLsgLqLju',
#     'id': '38O0SN9P3sC0UFLsgLqLju',
#     'is_local': False,
#     'name': 'Need A Little Time',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03ac36501d6b86b12803f6e3d9e5f7aa287d0a02?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:38O0SN9P3sC0UFLsgLqLju'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17mwzDXKn4ra9cuxXaptwp'},
#        'href': 'https://api.spotify.com/v1/artists/17mwzDXKn4ra9cuxXaptwp',
#        'id': '17mwzDXKn4ra9cuxXaptwp',
#        'name': 'Vagabon',
#        'type': 'artist',
#        'uri': 'spotify:artist:17mwzDXKn4ra9cuxXaptwp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3XS1FYnvexIhkkkLEkaEMX'},
#      'href': 'https://api.spotify.com/v1/albums/3XS1FYnvexIhkkkLEkaEMX',
#      'id': '3XS1FYnvexIhkkkLEkaEMX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273004ef98a2a626861ad597d33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02004ef98a2a626861ad597d33',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851004ef98a2a626861ad597d33',
#        'width': 64}],
#      'name': 'Reason to Believe (feat. Courtney Barnett)',
#      'release_date': '2021-01-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3XS1FYnvexIhkkkLEkaEMX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17mwzDXKn4ra9cuxXaptwp'},
#       'href': 'https://api.spotify.com/v1/artists/17mwzDXKn4ra9cuxXaptwp',
#       'id': '17mwzDXKn4ra9cuxXaptwp',
#       'name': 'Vagabon',
#       'type': 'artist',
#       'uri': 'spotify:artist:17mwzDXKn4ra9cuxXaptwp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 149445,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNO12000403'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7aDf2PpDNfT5NbKEIZVKtW'},
#     'href': 'https://api.spotify.com/v1/tracks/7aDf2PpDNfT5NbKEIZVKtW',
#     'id': '7aDf2PpDNfT5NbKEIZVKtW',
#     'is_local': False,
#     'name': 'Reason to Believe (feat. Courtney Barnett)',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e1368839ad30e248bc2a2297574794ab09aee90c?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7aDf2PpDNfT5NbKEIZVKtW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3pyor8OU0YfTNLtgjynv4I'},
#        'href': 'https://api.spotify.com/v1/artists/3pyor8OU0YfTNLtgjynv4I',
#        'id': '3pyor8OU0YfTNLtgjynv4I',
#        'name': 'RocKwiz',
#        'type': 'artist',
#        'uri': 'spotify:artist:3pyor8OU0YfTNLtgjynv4I'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/32sSQWOKjHqUUJh7zfllfn'},
#      'href': 'https://api.spotify.com/v1/albums/32sSQWOKjHqUUJh7zfllfn',
#      'id': '32sSQWOKjHqUUJh7zfllfn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c8b9f524a3b69b085446d98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c8b9f524a3b69b085446d98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c8b9f524a3b69b085446d98',
#        'width': 64}],
#      'name': 'Sunday Morning',
#      'release_date': '2015-09-28',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:32sSQWOKjHqUUJh7zfllfn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3pyor8OU0YfTNLtgjynv4I'},
#       'href': 'https://api.spotify.com/v1/artists/3pyor8OU0YfTNLtgjynv4I',
#       'id': '3pyor8OU0YfTNLtgjynv4I',
#       'name': 'RocKwiz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pyor8OU0YfTNLtgjynv4I'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yXAFDZNUNyO92l5WTImkO'},
#       'href': 'https://api.spotify.com/v1/artists/5yXAFDZNUNyO92l5WTImkO',
#       'id': '5yXAFDZNUNyO92l5WTImkO',
#       'name': 'Billy Bragg',
#       'type': 'artist',
#       'uri': 'spotify:artist:5yXAFDZNUNyO92l5WTImkO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4OOlG5eBXSkSAAEeKjJb5Y'},
#       'href': 'https://api.spotify.com/v1/artists/4OOlG5eBXSkSAAEeKjJb5Y',
#       'id': '4OOlG5eBXSkSAAEeKjJb5Y',
#       'name': 'Courtney Barnett',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 173000,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUKQA1200013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Xjb3DUx2mEJVMuQqI4K2K'},
#     'href': 'https://api.spotify.com/v1/tracks/2Xjb3DUx2mEJVMuQqI4K2K',
#     'id': '2Xjb3DUx2mEJVMuQqI4K2K',
#     'is_local': False,
#     'name': 'Sunday Morning (feat. Billy Bragg & Courtney Barnett)',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1f0a19bcb40e30b5593e37f33a9a721587039860?cid=ca650b927ecb47aeb87ac719d56bcfb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Xjb3DUx2mEJVMuQqI4K2K'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 18}}

# %%
results.keys() # we have a dictionary
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys() # a dictionary within a dictionary
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(results['tracks']['items']) # a list within a dictionary
# Out:
# 18

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['name'] # a dictionary inside a list (we get the value for the key name)
# Out:
# 'Avant Gardener'

# %% [markdown]
# Explore a single song:

# %%
results['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:3LueS3mbuB1yaJNN0Ale6U'

# %%
results['tracks']['items'][0]['id']
# Out:
# '3LueS3mbuB1yaJNN0Ale6U'

# %%
results['tracks']['items'][0]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/track/3LueS3mbuB1yaJNN0Ale6U'}

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri" or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.
#
# We'll use the `uri` in this code-along, but feel free to use whatever you think fits best your needs.

# %% [markdown]
# #### Searching multiple artists
#
# create a list of artists eg
#
# artists = ["Dire Straits", "Queen", "Ella Fitzgerald"]

# %%
# Create a list and assign it to a variable named my_20_artists.
my_20_artists = ['Fuel Fandango','Buhos','Sopa de cabra', 'Jack Johnson','Xavier Rudd', 'Ben Harper', 'The National', 'Bon Iver', 'Berri Txarrak', 'Iseo', 'Parov Stelar','Sum41', 'The Offspring','Rise Against', 'Billy Talent']

# %%
len(my_20_artists)
# Out:
# 15

# %%
# Loop over your 20 favorite artists and their results to the list.
my_artists_tracks = []
for artist in (my_20_artists):
    my_artists_tracks.append(sp.search(q={artist},limit=50))

# %%
len(my_artists_tracks)
# Out:
# 15

# %%
# Create a function that takes a list of artist names and return their 50 first appearances as a dictionary:
def artist_to_track_dictionary (my_20_artists):
    return {artist:sp.search(q=artist,limit=50) for artist in my_20_artists}

# %% [markdown]
# # Take a look at artists and albums

# %%
results['tracks']['items'][13].keys() 
# The items are the results of a search in Spotify
# Basically we should use positions or keys (depending on if each level is a nested list or dictionary)
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][13]['artists'][0]['name'] #artist name
# Out:
# 'Courtney Barnett'

# %%
results['tracks']['items'][13]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][13]['album']['name'] #album name
# Out:
# 'Things Take Time, Take Time'

# %% [markdown]
# #### Exploring the tracks

# %% [markdown]
# Function to get the artists involved in a song:

# %%
song_id = results['tracks']['items'][0]['id']

# %%
results['tracks']['items'][5]['artists'][1]['name']
# Out:
# 'Kurt Vile'

# %%
def artists (song_id):
    for i in range(len(results['tracks']['items'][5]['artists'])):
        print(results['tracks']['items'][5]['artists'][i]['name'])

# %%
artists('3LueS3mbuB1yaJNN0Ale6U')
# Out:
# Courtney Barnett
# Kurt Vile

# %% [markdown]
# Function to get the "id's" of the artists from a song:

# %%
def artists_id (song_id):
    for i in range(len(results['tracks']['items'][5]['artists'])):
        print(results['tracks']['items'][5]['artists'][i]['id'])

# %%
artists_id('3LueS3mbuB1yaJNN0Ale6U')
# Out:
# 4OOlG5eBXSkSAAEeKjJb5Y
# 5gspAQIAH8nJUrMYgXjCJ2

# %% [markdown]
# ### Playlists
#
# We will need to collect a "database" of songs. Playlists are a good way to access relatively large amounts of songs.

# %%
playlist = sp.user_playlist_tracks("spotify", "0Swkgrsji8x4cQWoJ4kfo2")

# %%
playlist_2 = sp.user_playlist_tracks("albertlluis", "5RwVtrLUXMlcPA39e5d8oM")

# %%
playlist_2["total"]
# Out:
# 53

# %%
playlist_2.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist_2['items'][0]['track']['id']
# Out:
# '4U0fzkyiRCxL08QJlQEM8B'

# %% [markdown]
# Function to extract all songs from a playlist

# %%
len(playlist_2['items'])
# Out:
# 53

# %%
song_list = []
def songsplay (playlist_2):
    for i in range(len(playlist_2['items'])):
        song_list.append(playlist_2['items'][i]['track']['id'])
        
# NOT FINISHED, check Sian's notebook

# %%
song_list
# Out:
# []

# %% [markdown]
# Function to extract just the uri's:

# %% [markdown]
# #### Pagination using "next"
#
# When you collect songs from a playlist using `sp.playlist_tracks`, you're limited by the `limit` parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter `offset` allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function `sp.next()` does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key `next` on the results from any request.

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %% [markdown]
# Above, we stored all the uri's of a playlist into a list called `iron_uris`. We're going to get all the audio features from that playlist's songs now.

# %% [markdown]
# ### Searching the audio features for a song
#
# When the user inputs a song, you are gonna want to retrieve the audio features of that song. How to do it?
#
# 1. Search the user input using the `sp.search()` function. This function works similarly to the "search" bar on the spotify app - using Spotify's intelligent search engine. That means that it can handle names of any songs or artists - even certain typos.
#
# 2. Find the uri of the song that the API gives you back.
#
# 3. Use `sp.audio_features` to retrieve the audio features of the song.

# %% [markdown]
# ### Lab: Create your collection of songs & audio features
#
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!
