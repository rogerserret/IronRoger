# %% [markdown]
# # Computer vision ethics
#
# Link: https://innodata.com/ethical-issues-in-computer-vision-and-strategies-for-success/#:~:text=Ethical%20Concerns%20in%20the%20Use,the%20lack%20of%20informed%20consent.
#
# This article shows different ethical issues in computer vision.
#
# From my point of view, one of the most important mentioned things is that "biases and discrimination are originated in the training data that is fed into a machine learning system". Many people blames AI of giving but results, but the main cause of them is the data we use to train our models. As our society is still racist and sexist, AI systems are trained with that bias, as it is the data that we have.

# %% [markdown]
# # Generated image

# %%
# my caption was: a giraffe flying on a cloud :)
# %matplotlib inline
from IPython.display import Image
Image('giraffe_cloud.png')

# %% [markdown]
# # Identifying cats and dogs

# %% [markdown]
# Link: https://thedatafrog.com/en/articles/dogs-vs-cats/
#
# It's important to never trust our data. In that example, we may have cat images that are not really representative and sometimes it's better to clean them up.
